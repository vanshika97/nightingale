# %%
import csv
import pandas as pd
import plotly.express as px

# %%
df = pd.read_excel("nightingale-data.xlsx", header=[0,1])

df.columns = df.columns.map('_'.join)
df.rename(columns ={"Unnamed: 0_level_0_Month":"Month", "Unnamed: 1_level_0_Average size of army":"Average size of army"},inplace=True)

# %%
df[df["Month"].str.contains("1855")]
# Out:
#        Month  Average size of army  Deaths_Zymotic diseases  \
# 9   Jan 1855                 32393                     2761
# 10  Feb 1855                 30919                     2120
# 11  Mar 1855                 30107                     1205
# 12  Apr 1855                 32252                      477
# 13  May 1855                 35473                      508
# 14  Jun 1855                 38863                      802
# 15  Jul 1855                 42647                      382
# 16  Aug 1855                 44614                      483
# 17  Sep 1855                 47751                      189
# 18  Oct 1855                 46852                      128
# 19  Nov 1855                 37853                      178
# 20  Dec 1855                 43217                       91
#
#     Deaths_Wounds & injuries  Deaths_All other causes  \
# 9                         83                      324
# 10                        42                      361
# ...
